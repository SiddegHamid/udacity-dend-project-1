# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files("./data/song_data")

# %%
filepath = song_files[0]

# %%
df = pd.DataFrame(pd.read_json(filepath, lines=True, orient='columns'))
df.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  AR7G5I41187FB4CE6C              NaN  London, England               NaN
#
#   artist_name   duration  num_songs             song_id            title  year
# 0    Adam Ant  233.40363          1  SONHOTT12A8C13493C  Something Girls  1982

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
# song ID, title, artist ID, year, and duration
song_data = (df.values[0][7], df.values[0][8], df.values[0][0], df.values[0][9], df.values[0][5])
song_data
# Out:
# ('SONHOTT12A8C13493C',
#  'Something Girls',
#  'AR7G5I41187FB4CE6C',
#  1982,
#  233.40363)

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
#NOTE: To prevent duplicates use "ON CONFLICT (song_id) DO NOTHING" in SQL query.
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
# artist ID, name, location, latitude, and longitude
artist_data = (df.values[0][0], df.values[0][4], df.values[0][2], df.values[0][1], df.values[0][3])
artist_data
# Out:
# ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan)

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
# #NOTE: To prevent duplicates use "ON CONFLICT (artist_id) DO NOTHING" in SQL query.
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files("./data/log_data")

# %%
filepath = log_files[0]

# %%
df = pd.DataFrame(pd.read_json(filepath, lines=True, orient='columns'))
df_orig = df
df
# Out:
#                          artist        auth firstName gender  itemInSession  \
# 0                      Frumpies   Logged In  Anabelle      F              0
# 1     Kenny G with Peabo Bryson   Logged In  Anabelle      F              1
# 2                   Biffy Clyro   Logged In  Anabelle      F              2
# 3                          None   Logged In      Lily      F              0
# 4                           HIM   Logged In      Lily      F              1
# 5                        Matmos   Logged In    Joseph      M              0
# 6                    Gary Allan   Logged In     Ryann      F              0
# 7              Miracle Fortress   Logged In     Ryann      F              1
# 8                      Don Omar   Logged In     Ryann      F              2
# 9                         Jay-Z   Logged In     Ryann      F              3
# 10        Red Hot Chili Peppers   Logged In     Ryann      F              4
# 11                         None   Logged In     Chloe      F              0
# 12               Flogging Molly   Logged In     Chloe      F              1
# 13         Reverend Horton Heat   Logged In     Chloe      F              2
# 14                     Sea Wolf   Logged In     Chloe      F              3
# 15  Jason Mraz & Colbie Caillat   Logged In     Chloe      F              4
# 16                 Jamie Lidell   Logged In     Chloe      F              5
# 17                        Feist   Logged In     Chloe      F              6
# 18                         None   Logged In     Chloe      F              7
# 19                         None  Logged Out      None   None              8
# 20                         None  Logged Out      None   None              9
# 21                         None  Logged Out      None   None             10
# 22                         None   Logged In     Chloe      F             11
# 23                   Sex Slaves   Logged In     Chloe      F             12
# 24                         None   Logged In     Chloe      F              0
# 25                 Rise Against   Logged In     Chloe      F              1
# 26                         None   Logged In  Mohammad      M              0
# 27                   BeyoncÃÂ©   Logged In  Mohammad      M              1
# 28                    Nate Dogg   Logged In  Mohammad      M              2
# 29                         None   Logged In    Cierra      F              0
# ..                          ...         ...       ...    ...            ...
# 65                 The Van Pelt   Logged In  Theodore      M              1
# 66                         None   Logged In      Ryan      M              0
# 67                          +44   Logged In      Ryan      M              1
# 68                         None   Logged In     Rylan      M              0
# 69                  Chris Brown   Logged In     Rylan      M              1
# 70                  KT Tunstall   Logged In      Ryan      M              2
# 71                      Cascada   Logged In     Rylan      M              2
# 72                      Incubus   Logged In      Ryan      M              3
# 73                         None   Logged In      Ryan      M              4
# 74                         None   Logged In      Ryan      M              5
# 75                         None   Logged In     Tegan      F              0
# 76                   Miike Snow   Logged In     Tegan      F              1
# 77                      Cartola   Logged In     Tegan      F              2
# 78              Kill The Client   Logged In     Tegan      F              3
# 79                         None   Logged In     Tegan      F              4
# 80                   Wolfmother   Logged In     Tegan      F              5
# 81       Old Crow Medicine Show   Logged In     Tegan      F              6
# 82     Architecture In Helsinki   Logged In     Tegan      F              7
# 83               Charlie Louvin   Logged In     Tegan      F              8
# 84               Miguel Morales   Logged In     Tegan      F              9
# 85                  Dominique A   Logged In     Tegan      F             10
# 86                 Cock Sparrer   Logged In     Tegan      F             11
# 87                 Jimmy Wakely   Logged In     Tegan      F             12
# 88                Peter Doherty   Logged In     Tegan      F             13
# 89                   Katy Perry   Logged In     Tegan      F             14
# 90            Sidewalk Prophets   Logged In     Molly      F              0
# 91                 Rise Against   Logged In     Molly      F              1
# 92                       K'Naan   Logged In     Molly      F              2
# 93               Patrick Jumpen   Logged In      Ryan      M              0
# 94                  Alicia Keys   Logged In      Ryan      M              1
#
#      lastName      length level                                     location  \
# 0     Simpson   134.47791  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 1     Simpson   264.75057  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 2     Simpson   189.83138  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 3       Burns         NaN  free        New York-Newark-Jersey City, NY-NJ-PA
# 4       Burns   212.06159  free        New York-Newark-Jersey City, NY-NJ-PA
# 5   Gutierrez  1449.11628  free                                 Columbia, SC
# 6       Smith   259.83955  free                                Palestine, TX
# 7       Smith   200.90730  free                                Palestine, TX
# 8       Smith   261.35465  free                                Palestine, TX
# 9       Smith   212.27057  free                                Palestine, TX
# 10      Smith   231.33995  free                                Palestine, TX
# 11     Cuevas         NaN  free            San Francisco-Oakland-Hayward, CA
# 12     Cuevas   361.95220  free            San Francisco-Oakland-Hayward, CA
# 13     Cuevas   158.64118  free            San Francisco-Oakland-Hayward, CA
# 14     Cuevas   232.61995  free            San Francisco-Oakland-Hayward, CA
# 15     Cuevas   189.62240  free            San Francisco-Oakland-Hayward, CA
# 16     Cuevas   175.25506  free            San Francisco-Oakland-Hayward, CA
# 17     Cuevas   212.79302  free            San Francisco-Oakland-Hayward, CA
# 18     Cuevas         NaN  free            San Francisco-Oakland-Hayward, CA
# 19       None         NaN  free                                         None
# 20       None         NaN  free                                         None
# 21       None         NaN  free                                         None
# 22     Cuevas         NaN  free            San Francisco-Oakland-Hayward, CA
# 23     Cuevas   175.51628  free            San Francisco-Oakland-Hayward, CA
# 24     Cuevas         NaN  free            San Francisco-Oakland-Hayward, CA
# 25     Cuevas   169.48200  free            San Francisco-Oakland-Hayward, CA
# 26  Rodriguez         NaN  free      Sacramento--Roseville--Arden-Arcade, CA
# 27  Rodriguez   359.54893  free      Sacramento--Roseville--Arden-Arcade, CA
# 28  Rodriguez   356.38812  free      Sacramento--Roseville--Arden-Arcade, CA
# 29     Finley         NaN  free                                 Richmond, VA
# ..        ...         ...   ...                                          ...
# 65     Harris   208.71791  free                                Red Bluff, CA
# 66      Smith         NaN  free           San Jose-Sunnyvale-Santa Clara, CA
# 67      Smith   224.57424  free           San Jose-Sunnyvale-Santa Clara, CA
# 68     George         NaN  free                        Birmingham-Hoover, AL
# 69     George   275.14730  free                        Birmingham-Hoover, AL
# 70      Smith   170.47465  free           San Jose-Sunnyvale-Santa Clara, CA
# 71     George   184.39791  free                        Birmingham-Hoover, AL
# 72      Smith   293.38077  free           San Jose-Sunnyvale-Santa Clara, CA
# 73      Smith         NaN  free           San Jose-Sunnyvale-Santa Clara, CA
# 74      Smith         NaN  free           San Jose-Sunnyvale-Santa Clara, CA
# 75     Levine         NaN  paid                  Portland-South Portland, ME
# 76     Levine   220.83873  paid                  Portland-South Portland, ME
# 77     Levine   208.92689  paid                  Portland-South Portland, ME
# 78     Levine    70.68689  paid                  Portland-South Portland, ME
# 79     Levine         NaN  paid                  Portland-South Portland, ME
# 80     Levine   175.82975  paid                  Portland-South Portland, ME
# 81     Levine   231.73179  paid                  Portland-South Portland, ME
# 82     Levine   173.73995  paid                  Portland-South Portland, ME
# 83     Levine   170.86649  paid                  Portland-South Portland, ME
# 84     Levine   270.78485  paid                  Portland-South Portland, ME
# 85     Levine   153.20771  paid                  Portland-South Portland, ME
# 86     Levine   203.25832  paid                  Portland-South Portland, ME
# 87     Levine   165.74649  paid                  Portland-South Portland, ME
# 88     Levine   217.02485  paid                  Portland-South Portland, ME
# 89     Levine   246.41261  paid                  Portland-South Portland, ME
# 90     Taylor   260.62322  free                             St. Louis, MO-IL
# 91     Taylor   221.17832  free                             St. Louis, MO-IL
# 92     Taylor   220.49914  free                             St. Louis, MO-IL
# 93      Smith   208.87465  free           San Jose-Sunnyvale-Santa Clara, CA
# 94      Smith   216.47628  free           San Jose-Sunnyvale-Santa Clara, CA
#
#    method      page  registration  sessionId  \
# 0     PUT  NextSong  1.541044e+12        455
# 1     PUT  NextSong  1.541044e+12        455
# 2     PUT  NextSong  1.541044e+12        455
# 3     GET      Home  1.540621e+12        456
# 4     PUT  NextSong  1.540621e+12        456
# 5     PUT  NextSong  1.540809e+12        284
# 6     PUT  NextSong  1.540685e+12        328
# 7     PUT  NextSong  1.540685e+12        328
# 8     PUT  NextSong  1.540685e+12        328
# 9     PUT  NextSong  1.540685e+12        328
# 10    PUT  NextSong  1.540685e+12        328
# 11    GET      Home  1.540941e+12        437
# 12    PUT  NextSong  1.540941e+12        437
# 13    PUT  NextSong  1.540941e+12        437
# 14    PUT  NextSong  1.540941e+12        437
# 15    PUT  NextSong  1.540941e+12        437
# 16    PUT  NextSong  1.540941e+12        437
# 17    PUT  NextSong  1.540941e+12        437
# 18    PUT    Logout  1.540941e+12        437
# 19    GET      Home           NaN        437
# 20    GET      Home           NaN        437
# 21    PUT     Login           NaN        437
# 22    GET      Home  1.540941e+12        437
# 23    PUT  NextSong  1.540941e+12        437
# 24    GET      Home  1.540941e+12        469
# 25    PUT  NextSong  1.540941e+12        469
# 26    GET      Home  1.540512e+12        441
# 27    PUT  NextSong  1.540512e+12        441
# 28    PUT  NextSong  1.540512e+12        441
# 29    GET      Home  1.541013e+12        443
# ..    ...       ...           ...        ...
# 65    PUT  NextSong  1.541097e+12        462
# 66    GET      Home  1.541017e+12        472
# 67    PUT  NextSong  1.541017e+12        472
# 68    GET      Home  1.541020e+12        446
# 69    PUT  NextSong  1.541020e+12        446
# 70    PUT  NextSong  1.541017e+12        472
# 71    PUT  NextSong  1.541020e+12        446
# 72    PUT  NextSong  1.541017e+12        472
# 73    GET      Help  1.541017e+12        472
# 74    GET      Home  1.541017e+12        472
# 75    GET      Home  1.540794e+12        435
# 76    PUT  NextSong  1.540794e+12        435
# 77    PUT  NextSong  1.540794e+12        435
# 78    PUT  NextSong  1.540794e+12        435
# 79    GET      Home  1.540794e+12        435
# 80    PUT  NextSong  1.540794e+12        435
# 81    PUT  NextSong  1.540794e+12        435
# 82    PUT  NextSong  1.540794e+12        435
# 83    PUT  NextSong  1.540794e+12        435
# 84    PUT  NextSong  1.540794e+12        435
# 85    PUT  NextSong  1.540794e+12        435
# 86    PUT  NextSong  1.540794e+12        435
# 87    PUT  NextSong  1.540794e+12        435
# 88    PUT  NextSong  1.540794e+12        435
# 89    PUT  NextSong  1.540794e+12        435
# 90    PUT  NextSong  1.540993e+12        464
# 91    PUT  NextSong  1.540993e+12        464
# 92    PUT  NextSong  1.540993e+12        464
# 93    PUT  NextSong  1.541017e+12        480
# 94    PUT  NextSong  1.541017e+12        480
#
#                                                song  status             ts  \
# 0                                        Fuck Kitty     200  1541903636796
# 1                    By The Time This Night Is Over     200  1541903770796
# 2                                       God & Satan     200  1541904034796
# 3                                              None     200  1541910841796
# 4                                         Beautiful     200  1541910973796
# 5                                   Supreme Balloon     200  1541911006796
# 6                                           The One     200  1541930188796
# 7                                        Five Roses     200  1541930447796
# 8                                          Cuentale     200  1541930647796
# 9                                           D'Evils     200  1541930908796
# 10                           Easily (Album Version)     200  1541931120796
# 11                                             None     200  1541932052796
# 12                       Rebels of the Sacred Heart     200  1541932063796
# 13                                   Now_ Right Now     200  1541932424796
# 14                              I Made A Resolution     200  1541932582796
# 15                            Lucky (Album Version)     200  1541932814796
# 16                                  Enoughs Enough     200  1541933003796
# 17                   Mushaboom (Postal Service Mix)     200  1541933178796
# 18                                             None     307  1541933179796
# 19                                             None     200  1541933298796
# 20                                             None     200  1541934031796
# 21                                             None     307  1541934032796
# 22                                             None     200  1541934168796
# 23                          We're Going Out Tonight     200  1541934891796
# 24                                             None     200  1541943439796
# 25                     To Them These Streets Belong     200  1541943682796
# 26                                             None     200  1541944080796
# 27                                    Get Me Bodied     200  1541944343796
# 28                             Never Leave Me Alone     200  1541944702796
# 29                                             None     200  1541945130796
# ..                                              ...     ...            ...
# 65                                   It's New To Me     200  1541959713796
# 66                                             None     200  1541962018796
# 67                                   Make You Smile     200  1541962092796
# 68                                             None     200  1541962134796
# 69                                 I May Never Find     200  1541962141796
# 70  Black Horse And The Cherry Tree (Radio Version)     200  1541962316796
# 71                                  Kids In America     200  1541962416796
# 72                              Black Heart Inertia     200  1541962486796
# 73                                             None     200  1541962633796
# 74                                             None     200  1541962656796
# 75                                             None     200  1541965304796
# 76                                     Black & Blue     200  1541965305796
# 77                           Sala De RecepÃÂ§ÃÂ£o     200  1541965525796
# 78                               Commander In Thief     200  1541965733796
# 79                                             None     200  1541965947796
# 80                                            Woman     200  1541966183796
# 81                                      Wagon Wheel     200  1541966358796
# 82                                           Debbie     200  1541966589796
# 83                                I Think I'll Live     200  1541966762796
# 84                        La Derrota de Un Don Juan     200  1541966932796
# 85                           Le Courage Des Oiseaux     200  1541967202796
# 86                               Run With The Blind     200  1541967355796
# 87                      I Love You So Much It Hurts     200  1541967558796
# 88                   A Little Death Around the Eyes     200  1541967723796
# 89                                  Thinking Of You     200  1541967940796
# 90                       You Love Me Anyway (Album)     200  1541970568796
# 91                                          Torches     200  1541970828796
# 92                                     Wavin'  Flag     200  1541971049796
# 93                                          Holiday     200  1541979540796
# 94       Empire State Of Mind (Part II) Broken Down     200  1541979748796
#
#                                             userAgent userId
# 0   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     69
# 1   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     69
# 2   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     69
# 3   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     32
# 4   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     32
# 5   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3...     75
# 6   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     92
# 7   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     92
# 8   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     92
# 9   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     92
# 10  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     92
# 11  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 12  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 13  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 14  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 15  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 16  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 17  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 18  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 19                                               None
# 20                                               None
# 21                                               None
# 22  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 23  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 24  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 25  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 26  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     88
# 27  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     88
# 28  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     88
# 29  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     96
# ..                                                ...    ...
# 65  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...     14
# 66  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 67  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 68  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 69  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 70  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 71  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 72  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 73  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 74  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 75  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 76  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 77  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 78  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 79  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 80  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 81  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 82  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 83  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 84  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 85  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 86  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 87  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 88  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 89  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 90  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     35
# 91  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     35
# 92  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     35
# 93  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 94  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
#
# [95 rows x 18 columns]

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
# See: https://cmdlinetips.com/2018/02/how-to-subset-pandas-dataframe-based-on-values-of-a-column/
# "filter rows for year 2002 using  the boolean variable"
# df['page']=='NextSong' tells if record has NextSong value in page columns (true/false).
# df[df['page']=='NextSong'] filters those records == leaves out records having some other value.
df = df[df['page']=='NextSong']
#df.head()

# %%
t = pd.to_datetime(df['ts'], unit='ms')
#t.head()

# %%
# See: https://www.geeksforgeeks.org/different-ways-to-create-pandas-dataframe/
# See: https://stackoverflow.com/questions/44741587/pandas-timestamp-series-to-string
time_data = list(zip(t.dt.strftime('%Y-%m-%d %I:%M:%S'), t.dt.hour, t.dt.day, t.dt.week, t.dt.month, t.dt.year, t.dt.weekday))
column_labels = ('start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday')
#time_data

# %%
time_df = pd.DataFrame(time_data, columns=column_labels)

for i, row in time_df.iterrows():
    print(list(row))

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_data = df_orig.get(['userId', 'firstName', 'lastName', 'gender', 'level'])
# adjust column names
user_data.columns = ['user_id', 'first_name', 'last_name', 'gender', 'level']
# remove rows with no user_id
user_data_clean = user_data[user_data['user_id']!= '']
# remove duplicates
user_data_duplicates_removed = user_data_clean.drop_duplicates('user_id', keep='first')

user_df = user_data_duplicates_removed
#user_df

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
# #NOTE: To prevent duplicates use "ON CONFLICT (user_id) DO NOTHING" in SQL query.
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
# NOTE: In Postgresql, use %s as a string operator for incoming variables
# e.g. INSERT ...VALUES (%s, %s) or SELECT ...WHERE s.name = %s AND a.artist_id = %s AND s.length = %s
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
    #print(songid, artistid)
    
    start_time = pd.to_datetime(row.ts, unit='ms').strftime('%Y-%m-%d %I:%M:%S')
    songplay_data = (start_time, row.userId, row.level, str(songid), str(artistid), row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
